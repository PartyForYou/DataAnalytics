# %%
import pandas as pd
pd.read_csv("전국종량제봉투가격표준데이터.csv", encoding="cp949")
# Out:
#       시도명 시군구명  종량제봉투종류 종량제봉투처리방식 종량제봉투용도 종량제봉투사용대상  1ℓ가격  1.5ℓ가격  2ℓ가격  \
# 0     경기도  안양시     규격봉투       매립용   생활쓰레기      사업장용     0       0     0
# 1     경기도  안양시     규격봉투       매립용   생활쓰레기        기타     0       0     0
# 2     경기도  안양시     규격봉투       소각용  음식물쓰레기       가정용     0      50     0
# 3     경기도  안양시     규격봉투       소각용  음식물쓰레기      사업장용     0      50     0
# 4     경기도  안양시     규격봉투       소각용  음식물쓰레기        기타     0      50     0
# ..    ...  ...      ...       ...     ...       ...   ...     ...   ...
# 748  충청남도  계룡시  재사용규격봉투       소각용   생활쓰레기       가정용     0       0     0
# 749  충청남도  계룡시  재사용규격봉투       소각용   생활쓰레기      사업장용     0       0     0
# 750  전라북도  김제시     규격봉투       소각용   생활쓰레기       가정용     0       0     0
# 751  전라북도  김제시   특수규격마대       매립용   생활쓰레기       가정용     0       0     0
# 752  전라북도  김제시    김장용봉투       소각용  음식물쓰레기       가정용     0       0     0
#
#      2.5ℓ가격  ...  60ℓ가격  75ℓ가격  100ℓ가격  120ℓ가격  125ℓ가격  관리부서명       관리부서전화번호  \
# 0         0  ...      0   2100       0       0       0  자원순환과  031-8045-5448
# 1         0  ...      0   2100       0       0       0  자원순환과  031-8045-5448
# 2        80  ...      0      0       0       0       0  자원순환과  031-8045-5448
# 3        80  ...      0      0       0       0       0  자원순환과  031-8045-5448
# 4        80  ...      0      0       0       0       0  자원순환과  031-8045-5448
# ..      ...  ...    ...    ...     ...     ...     ...    ...            ...
# 748       0  ...      0      0    2320       0       0  환경위생과   042-840-2484
# 749       0  ...      0      0    2320       0       0  환경위생과   042-840-2484
# 750       0  ...      0      0       0       0       0    환경과   063-540-3165
# 751       0  ...      0      0       0       0       0    환경과   063-540-3165
# 752       0  ...      0      0       0       0       0    환경과   063-540-3165
#
#         데이터기준일자   제공기관코드     제공기관명
# 0    2022-08-12  3830000   경기도 안양시
# 1    2022-08-12  3830000   경기도 안양시
# 2    2022-08-12  3830000   경기도 안양시
# 3    2022-08-12  3830000   경기도 안양시
# 4    2022-08-12  3830000   경기도 안양시
# ..          ...      ...       ...
# 748  2019-05-16  5580000  충청남도 계룡시
# 749  2019-05-16  5580000  충청남도 계룡시
# 750  2018-08-09  4710000  전라북도 김제시
# 751  2018-08-09  4710000  전라북도 김제시
# 752  2018-08-09  4710000  전라북도 김제시
#
# [753 rows x 26 columns]

# %% [markdown]
# - 소괄호() 안에서 shift + tab 키를 누르면 도움말을 볼 수 있습니다.
#
#
# - csv파일을 불러올 때 한글파일 인코딩을 하지 않으면 오류가 나기 때문에 encoding="cp949"를 함께 적어주셔야 합니다.
#
#
# - "euc-kr"을 적는 방법도 있지만 일부 한글은 깨지기 때문에 "cp949"를 사용하시는 것을 추천드립니다.
